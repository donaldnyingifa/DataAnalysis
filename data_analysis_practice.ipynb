# %%
import pandas as pd
data = pd.read_csv('./data/spe_threatened_ng.csv')
cm = pd.read_csv('./data/climate.csv')

# %%
df = pd.DataFrame({'lab':['P', 'Q', 'R'], 'val':[20, 40, 30]})
ax = df.plot.bar(x='lab', y='val', rot=0)

# %%
cm
# Out:
#                         Climate   January  February  March  April    May  \
# 0          Avg. Temperature (°C)     26.9      27.7   28.1   27.7   27.0
# 1          Min. Temperature (°C)     22.4      23.3   23.9   23.6   22.9
# 2          Max. Temperature (°C)     31.5      32.1   32.3   31.9   31.2
# 3          Avg. Temperature (°F)     80.4      81.9   82.6   81.9   80.6
# 4          Min. Temperature (°F)     72.3      73.9   75.0   74.5   73.2
# 5          Max. Temperature (°F)     88.7      89.8   90.1   89.4   88.2
# 6  Precipitation / Rainfall (mm)     47.0      86.0  153.0  217.0  305.0
#
#     June   July  August  September  October  November  December
# 0   26.4   25.4    25.4       25.8     26.1      26.8      27.0
# 1   22.6   22.0    22.3       22.3     22.5      22.9      22.8
# 2   30.3   28.8    28.6       29.3     29.8      30.8      31.2
# 3   79.5   77.7    77.7       78.4     79.0      80.2      80.6
# ...

# %%
data
# Out:
#   threathened group  Total number of species  number found only in nigeria
# 0            plants                    171.0                           0.0
# 1           mammals                      NaN                           3.0
# 2             birds                     12.0                           3.0
# 3          reptiles                      3.0                           NaN
# 4        amphibians                     13.0                           5.0
# 5  fresh water fish                     21.0                           0.0
# 6     invertebrates                      1.0                           0.0

# %%
#jan = list(data['January'])
#feb = list(data['February'])

col_names = cm.columns[1:]
col_names
# Out:
# Index(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
species = list(data['Total number of species'])
nigeria = list(data['number found only in nigeria'])
index = data['threathened group']
df = pd.DataFrame({'Total number of species': species,
                   'Number found only in nigeria': nigeria}, index=index)
#ax = df.plot.bar()
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#                    Total number of species  Number found only in nigeria
# threathened group
# plants                               171.0                           0.0
# mammals                               91.5                           3.0
# birds                                 12.0                           3.0
# reptiles                               3.0                           4.0
# amphibians                            13.0                           5.0
# fresh water fish                      21.0                           0.0
# invertebrates                          1.0                           0.0

# %%
speed = [0.2, 18.5, 50, 68, 72, 84, 98]
lifespan = [3, 9, 80, 5.5, 35, 22, 38]
index = ['snail', 'goat', 'elephant',
         'dog', 'cat', 'fox', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
# Out:
#           speed  lifespan
# snail       0.2       3.0
# goat       18.5       9.0
# elephant   50.0      80.0
# dog        68.0       5.5
# cat        72.0      35.0
# fox        84.0      22.0
# horse      98.0      38.0

# %%
data
# Out:
#   threathened group  Total number of species  number found only in nigeria
# 0            plants                    171.0                           0.0
# 1           mammals                      NaN                           3.0
# 2             birds                     12.0                           3.0
# 3          reptiles                      3.0                           NaN
# 4        amphibians                     13.0                           5.0
# 5  fresh water fish                     21.0                           0.0
# 6     invertebrates                      1.0                           0.0

# %%
ax = df.plot.bar()

# %%
speed
# Out:
# [0.2, 18.5, 50, 68, 72, 84, 98]

# %%
from mpl_toolkits.basemap import Basemap

import matplotlib.pyplot as plt

import numpy as np

# %matplotlib inline 

import warnings

import matplotlib.cbook

warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

 

 

Basemap?

 

 

fig = plt.figure(num=None, figsize=(12, 8) )

m = Basemap(projection='merc',llcrnrlat=-80,urcrnrlat=80,llcrnrlon=-180,urcrnrlon=180,resolution='c')

m.drawcoastlines()

plt.title("Mercator Projection")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-91-3294e92a9577> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2
#       3 import matplotlib.pyplot as plt
#       4
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
